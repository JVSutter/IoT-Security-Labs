# %% [markdown]
# # Lab 2 - IoT Security
#
# ### Q1
#
# importing required librarys

# %%
import numpy as np
import pandas as pd
import flwr
import flask

# %% [markdown]
# read csv and partition it into 5 partitions, for different devices

# %%
ddos = pd.read_csv('DDoS-HTTP_Flood-.pcap.csv')
number_devices = 7
rows_per_device = ddos.shape[0] // number_devices

ddos.head()
# Out:
#    Header_Length  Protocol Type  Time_To_Live         Rate  fin_flag_number  \
# 0          33.76              6         67.82   497.069706             0.04
# 1          34.32              6         65.91   300.155291             0.21
# 2          36.00              6         64.00  1768.032711             0.08
# 3          37.72              6         65.91   985.075566             0.25
# 4          38.28              6         65.91  1074.735051             0.12
#
#    syn_flag_number  rst_flag_number  psh_flag_number  ack_flag_number  \
# 0             0.13             0.11             0.05             0.84
# 1             0.38             0.08             0.11             0.83
# 2             0.34             0.04             0.08             0.93
# 3             0.04             0.01             0.15             0.98
# 4             0.41             0.02             0.09             0.96
#
#    ece_flag_number  ...  LLC  Tot sum  Min   Max     AVG         Std  \
# ...

# %%
# split into number of devices
splitted_ddos = [ddos[i*rows_per_device:(i+1)*rows_per_device].copy() for i in range(0,number_devices)]

print(ddos.shape)
for device in splitted_ddos:
   print(device.shape)
   #print(device.head())
# Out:
# (28790, 39)
# (4112, 39)
#    Header_Length  Protocol Type  Time_To_Live         Rate  fin_flag_number  \
# 0          33.76              6         67.82   497.069706             0.04
# 1          34.32              6         65.91   300.155291             0.21
# 2          36.00              6         64.00  1768.032711             0.08
# 3          37.72              6         65.91   985.075566             0.25
# 4          38.28              6         65.91  1074.735051             0.12
#
#    syn_flag_number  rst_flag_number  psh_flag_number  ack_flag_number  \
# 0             0.13             0.11             0.05             0.84
# 1             0.38             0.08             0.11             0.83
# 2             0.34             0.04             0.08             0.93
# 3             0.04             0.01             0.15             0.98
# 4             0.41             0.02             0.09             0.96
#
# ...
